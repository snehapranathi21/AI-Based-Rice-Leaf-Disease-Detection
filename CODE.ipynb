# %%
import tensorflow as tf
print(f"Num Gpu Avaiable Are : {len(tf.config.list_physical_devices('GPU'))}")
# Out:
# Num Gpu Avaiable Are : 1

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# import seaborn as sns
import cv2
import os, glob
import tensorflow as tf
from tqdm import tqdm
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Model, Sequential, load_model
from tensorflow.keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D, BatchNormalization, AveragePooling2D,GlobalAveragePooling2D,Input
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import warnings
warnings.filterwarnings("ignore",category=DeprecationWarning)

# %%
data_train = r"./Dataset/train"
data_test = r"./Dataset/validation"
fake=[]
for file in os.listdir(data_test):
    if file[0] =='.':
        continue
    fake+=[file]
print(fake)
print(len(fake))
# for file1 in os.listdir(data_train):
#     if file1[0] =='.':
#         continue
#     fake+=[file1]
# print(fake)
# print(len(fake))
# Out:
# ['bacterial_leaf_blight', 'brown_spot', 'healthy', 'leaf_blast', 'leaf_scald', 'narrow_brown_spot']
# 6

# %%
img_height,img_width=256,256
batch_size=20

train_datagen = ImageDataGenerator(rescale=1./255)
train_generator = train_datagen.flow_from_directory(data_train,
                                                target_size=(img_height,img_width),
                                                batch_size=batch_size,
                                                class_mode='categorical',
                                               )
test_generator = train_datagen.flow_from_directory(data_test,
                                                target_size=(img_height,img_width),
                                                batch_size=batch_size,
                                                class_mode='categorical',
                               
                                               )
# Out:
# Found 2100 images belonging to 6 classes.
# Found 528 images belonging to 6 classes.

# %%
precision=tf.keras.metrics.Precision()
recall=tf.keras.metrics.Recall()
sensitivity=tf.keras.metrics.SensitivityAtSpecificity(0.1)
specificity=tf.keras.metrics.SpecificityAtSensitivity(0.1)

# %%
from sklearn.metrics import confusion_matrix
def plot_confusion_matrix(y_true, y_pred, classes,
                          normalize=False,
                          title=None,
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if not title:
        if normalize:
            title = 'Normalized confusion matrix'
        else:
            title = 'Confusion matrix, without normalization'

    # Compute confusion matrix
    cm = confusion_matrix(y_true, y_pred)
    # Only use the labels that appear in the data
    classes = classes
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    fig, ax = plt.subplots()
    im = ax.imshow(cm, interpolation='nearest', cmap=cmap)
    ax.figure.colorbar(im, ax=ax)
    # We want to show all ticks...
    ax.set(xticks=np.arange(cm.shape[1]),
           yticks=np.arange(cm.shape[0]),
           # ... and label them with the respective list entries
           xticklabels=classes, yticklabels=classes,
           title=title,
           ylabel='True label',
           xlabel='Predicted label')

    # Rotate the tick labels and set their alignment.
    plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
             rotation_mode="anchor")

    # Loop over data dimensions and create text annotations.
    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            ax.text(j, i, format(cm[i, j], fmt),
                    ha="center", va="center",
                    color="white" if cm[i, j] > thresh else "black")
    fig.tight_layout()
    return ax

# %% [markdown]
# ## CNN

# %%
model = Sequential()

model.add(Conv2D(filters = 32, kernel_size = (5,5),padding = 'Same', 
                 activation ='relu', input_shape = (img_height,img_width,3)))
model.add(Conv2D(filters = 32, kernel_size = (5,5),padding = 'Same', 
                 activation ='relu'))
model.add(MaxPool2D(pool_size=(2,2)))


model.add(Conv2D(filters = 64, kernel_size = (3,3),padding = 'Same', 
                 activation ='relu'))
model.add(Conv2D(filters = 64, kernel_size = (3,3),padding = 'Same', 
                 activation ='relu'))
model.add(MaxPool2D(pool_size=(2,2), strides=(2,2)))

model.add(Flatten())
model.add(Dense(256, activation = "relu"))

model.add(Dense(6, activation = "softmax"))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 256, 256, 32)      2432
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 256, 256, 32)      25632
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 128, 128, 32)      0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 128, 128, 64)      18496
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 128, 128, 64)      36928
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 64, 64, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 262144)            0
# _________________________________________________________________
# dense (Dense)                (None, 256)               67109120
# _________________________________________________________________
# dense_1 (Dense)              (None, 6)                 1542
# =================================================================
# Total params: 67,194,150
# Trainable params: 67,194,150
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer="adam",loss="categorical_crossentropy",metrics=['accuracy',precision,recall,sensitivity,specificity])
hist=model.fit(train_generator,epochs=50,validation_data=test_generator)
# Out:
# Epoch 1/50
# 105/105 [==============================] - 110s 918ms/step - loss: 2.5521 - accuracy: 0.2071 - precision: 0.2542 - recall: 0.0071 - sensitivity_at_specificity: 0.9152 - specificity_at_sensitivity: 0.9242 - val_loss: 1.5750 - val_accuracy: 0.3106 - val_precision: 0.4508 - val_recall: 0.1648 - val_sensitivity_at_specificity: 0.9848 - val_specificity_at_sensitivity: 0.9871
# Epoch 2/50
# 105/105 [==============================] - 63s 598ms/step - loss: 1.3148 - accuracy: 0.4881 - precision: 0.6061 - recall: 0.2176 - sensitivity_at_specificity: 0.9952 - specificity_at_sensitivity: 0.9920 - val_loss: 1.1513 - val_accuracy: 0.5549 - val_precision: 0.7169 - val_recall: 0.2973 - val_sensitivity_at_specificity: 1.0000 - val_specificity_at_sensitivity: 0.9985
# Epoch 3/50
# 105/105 [==============================] - 52s 492ms/step - loss: 0.9911 - accuracy: 0.6076 - precision: 0.7032 - recall: 0.4581 - sensitivity_at_specificity: 0.9986 - specificity_at_sensitivity: 0.9990 - val_loss: 0.9995 - val_accuracy: 0.6496 - val_precision: 0.7188 - val_recall: 0.5227 - val_sensitivity_at_specificity: 0.9886 - val_specificity_at_sensitivity: 0.9996
# Epoch 4/50
# 105/105 [==============================] - 52s 494ms/step - loss: 0.8286 - accuracy: 0.6733 - precision: 0.7448 - recall: 0.5767 - sensitivity_at_specificity: 0.9986 - specificity_at_sensitivity: 0.9999 - val_loss: 0.9550 - val_accuracy: 0.6212 - val_precision: 0.7108 - val_recall: 0.5492 - val_sensitivity_at_specificity: 0.9905 - val_specificity_at_sensitivity: 0.9996
# Epoch 5/50
# 105/105 [==============================] - 54s 518ms/step - loss: 0.6873 - accuracy: 0.7300 - precision: 0.8001 - recall: 0.6519 - sensitivity_at_specificity: 0.9981 - specificity_at_sensitivity: 0.9999 - val_loss: 0.9642 - val_accuracy: 0.6629 - val_precision: 0.7169 - val_recall: 0.6042 - val_sensitivity_at_specificity: 0.9848 - val_specificity_at_sensitivity: 0.9989
# Epoch 6/50
# 105/105 [==============================] - 52s 494ms/step - loss: 0.6260 - accuracy: 0.7671 - precision: 0.8275 - recall: 0.7033 - sensitivity_at_specificity: 0.9971 - specificity_at_sensitivity: 0.9997 - val_loss: 1.0798 - val_accuracy: 0.6345 - val_precision: 0.6890 - val_recall: 0.5833 - val_sensitivity_at_specificity: 0.9697 - val_specificity_at_sensitivity: 0.9989
# Epoch 7/50
# 105/105 [==============================] - 52s 497ms/step - loss: 0.4911 - accuracy: 0.8238 - precision: 0.8730 - recall: 0.7757 - sensitivity_at_specificity: 0.9981 - specificity_at_sensitivity: 0.9999 - val_loss: 0.9216 - val_accuracy: 0.7008 - val_precision: 0.7575 - val_recall: 0.6686 - val_sensitivity_at_specificity: 0.9621 - val_specificity_at_sensitivity: 0.9962
# Epoch 8/50
# 105/105 [==============================] - 53s 502ms/step - loss: 0.3632 - accuracy: 0.8657 - precision: 0.8935 - recall: 0.8386 - sensitivity_at_specificity: 0.9971 - specificity_at_sensitivity: 1.0000 - val_loss: 1.0531 - val_accuracy: 0.7121 - val_precision: 0.7484 - val_recall: 0.6648 - val_sensitivity_at_specificity: 0.9564 - val_specificity_at_sensitivity: 0.9951
# Epoch 9/50
# 105/105 [==============================] - 53s 505ms/step - loss: 0.2090 - accuracy: 0.9329 - precision: 0.9448 - recall: 0.9205 - sensitivity_at_specificity: 0.9976 - specificity_at_sensitivity: 0.9998 - val_loss: 1.0611 - val_accuracy: 0.7670 - val_precision: 0.7762 - val_recall: 0.7424 - val_sensitivity_at_specificity: 0.9470 - val_specificity_at_sensitivity: 0.9932
# Epoch 10/50
# 105/105 [==============================] - 54s 512ms/step - loss: 0.2330 - accuracy: 0.9238 - precision: 0.9354 - recall: 0.9100 - sensitivity_at_specificity: 0.9986 - specificity_at_sensitivity: 1.0000 - val_loss: 1.3922 - val_accuracy: 0.6970 - val_precision: 0.7240 - val_recall: 0.6856 - val_sensitivity_at_specificity: 0.9205 - val_specificity_at_sensitivity: 0.9924
# Epoch 11/50
# 105/105 [==============================] - 55s 525ms/step - loss: 0.1700 - accuracy: 0.9390 - precision: 0.9514 - recall: 0.9319 - sensitivity_at_specificity: 0.9990 - specificity_at_sensitivity: 0.9999 - val_loss: 1.6323 - val_accuracy: 0.7121 - val_precision: 0.7294 - val_recall: 0.7045 - val_sensitivity_at_specificity: 0.8864 - val_specificity_at_sensitivity: 0.9886
# Epoch 12/50
# 105/105 [==============================] - 56s 532ms/step - loss: 0.0909 - accuracy: 0.9686 - precision: 0.9712 - recall: 0.9629 - sensitivity_at_specificity: 0.9990 - specificity_at_sensitivity: 0.9999 - val_loss: 1.5789 - val_accuracy: 0.6970 - val_precision: 0.7029 - val_recall: 0.6856 - val_sensitivity_at_specificity: 0.9053 - val_specificity_at_sensitivity: 0.9894
# Epoch 13/50
# 105/105 [==============================] - 55s 527ms/step - loss: 0.0668 - accuracy: 0.9771 - precision: 0.9790 - recall: 0.9748 - sensitivity_at_specificity: 0.9990 - specificity_at_sensitivity: 0.9999 - val_loss: 1.6073 - val_accuracy: 0.7443 - val_precision: 0.7457 - val_recall: 0.7330 - val_sensitivity_at_specificity: 0.8996 - val_specificity_at_sensitivity: 0.9894
# Epoch 14/50
# 105/105 [==============================] - 54s 512ms/step - loss: 0.0771 - accuracy: 0.9748 - precision: 0.9766 - recall: 0.9719 - sensitivity_at_specificity: 0.9990 - specificity_at_sensitivity: 0.9999 - val_loss: 1.4593 - val_accuracy: 0.7386 - val_precision: 0.7495 - val_recall: 0.7311 - val_sensitivity_at_specificity: 0.9072 - val_specificity_at_sensitivity: 0.9898
# Epoch 15/50
# 105/105 [==============================] - 54s 512ms/step - loss: 0.0233 - accuracy: 0.9938 - precision: 0.9947 - recall: 0.9924 - sensitivity_at_specificity: 1.0000 - specificity_at_sensitivity: 1.0000 - val_loss: 2.0811 - val_accuracy: 0.7462 - val_precision: 0.7510 - val_recall: 0.7367 - val_sensitivity_at_specificity: 0.8598 - val_specificity_at_sensitivity: 0.9833
# Epoch 16/50
# 105/105 [==============================] - 55s 519ms/step - loss: 0.1170 - accuracy: 0.9657 - precision: 0.9707 - recall: 0.9614 - sensitivity_at_specificity: 0.9981 - specificity_at_sensitivity: 0.9998 - val_loss: 1.8677 - val_accuracy: 0.7273 - val_precision: 0.7344 - val_recall: 0.7121 - val_sensitivity_at_specificity: 0.8731 - val_specificity_at_sensitivity: 0.9848
# Epoch 17/50
# 105/105 [==============================] - 54s 516ms/step - loss: 0.0420 - accuracy: 0.9900 - precision: 0.9914 - recall: 0.9895 - sensitivity_at_specificity: 0.9995 - specificity_at_sensitivity: 0.9999 - val_loss: 1.3438 - val_accuracy: 0.7708 - val_precision: 0.7823 - val_recall: 0.7689 - val_sensitivity_at_specificity: 0.9053 - val_specificity_at_sensitivity: 0.9905
# Epoch 18/50
# 105/105 [==============================] - 54s 518ms/step - loss: 0.0235 - accuracy: 0.9929 - precision: 0.9933 - recall: 0.9924 - sensitivity_at_specificity: 0.9995 - specificity_at_sensitivity: 0.9999 - val_loss: 1.9831 - val_accuracy: 0.7254 - val_precision: 0.7283 - val_recall: 0.7159 - val_sensitivity_at_specificity: 0.8750 - val_specificity_at_sensitivity: 0.9841
# Epoch 19/50
# 105/105 [==============================] - 57s 542ms/step - loss: 0.0363 - accuracy: 0.9933 - precision: 0.9933 - recall: 0.9933 - sensitivity_at_specificity: 0.9990 - specificity_at_sensitivity: 0.9998 - val_loss: 1.7539 - val_accuracy: 0.7614 - val_precision: 0.7686 - val_recall: 0.7614 - val_sensitivity_at_specificity: 0.8826 - val_specificity_at_sensitivity: 0.9871
# Epoch 20/50
# 105/105 [==============================] - 55s 520ms/step - loss: 0.0090 - accuracy: 0.9971 - precision: 0.9976 - recall: 0.9971 - sensitivity_at_specificity: 1.0000 - specificity_at_sensitivity: 1.0000 - val_loss: 1.8270 - val_accuracy: 0.7652 - val_precision: 0.7672 - val_recall: 0.7614 - val_sensitivity_at_specificity: 0.8693 - val_specificity_at_sensitivity: 0.9848
# Epoch 21/50
# 105/105 [==============================] - 54s 512ms/step - loss: 0.0633 - accuracy: 0.9895 - precision: 0.9905 - recall: 0.9890 - sensitivity_at_specificity: 0.9976 - specificity_at_sensitivity: 0.9996 - val_loss: 1.7924 - val_accuracy: 0.7557 - val_precision: 0.7639 - val_recall: 0.7538 - val_sensitivity_at_specificity: 0.8826 - val_specificity_at_sensitivity: 0.9848
# Epoch 22/50
# 105/105 [==============================] - 55s 525ms/step - loss: 0.0055 - accuracy: 0.9990 - precision: 0.9990 - recall: 0.9990 - sensitivity_at_specificity: 1.0000 - specificity_at_sensitivity: 1.0000 - val_loss: 1.9230 - val_accuracy: 0.7689 - val_precision: 0.7733 - val_recall: 0.7689 - val_sensitivity_at_specificity: 0.8807 - val_specificity_at_sensitivity: 0.9841
# Epoch 23/50
# 105/105 [==============================] - 55s 520ms/step - loss: 5.1271e-04 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - sensitivity_at_specificity: 1.0000 - specificity_at_sensitivity: 1.0000 - val_loss: 2.0627 - val_accuracy: 0.7708 - val_precision: 0.7738 - val_recall: 0.7708 - val_sensitivity_at_specificity: 0.8712 - val_specificity_at_sensitivity: 0.9822
# Epoch 24/50
# 105/105 [==============================] - 55s 525ms/step - loss: 1.9775e-04 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - sensitivity_at_specificity: 1.0000 - specificity_at_sensitivity: 1.0000 - val_loss: 2.1234 - val_accuracy: 0.7708 - val_precision: 0.7748 - val_recall: 0.7689 - val_sensitivity_at_specificity: 0.8712 - val_specificity_at_sensitivity: 0.9811
# Epoch 25/50
# 105/105 [==============================] - 54s 511ms/step - loss: 1.0518e-04 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - sensitivity_at_specificity: 1.0000 - specificity_at_sensitivity: 1.0000 - val_loss: 2.1629 - val_accuracy: 0.7689 - val_precision: 0.7748 - val_recall: 0.7689 - val_sensitivity_at_specificity: 0.8712 - val_specificity_at_sensitivity: 0.9807
# Epoch 26/50
# 105/105 [==============================] - 54s 517ms/step - loss: 8.5121e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - sensitivity_at_specificity: 1.0000 - specificity_at_sensitivity: 1.0000 - val_loss: 2.2003 - val_accuracy: 0.7689 - val_precision: 0.7748 - val_recall: 0.7689 - val_sensitivity_at_specificity: 0.8693 - val_specificity_at_sensitivity: 0.9803
# Epoch 27/50
# 105/105 [==============================] - 54s 517ms/step - loss: 7.0393e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - sensitivity_at_specificity: 1.0000 - specificity_at_sensitivity: 1.0000 - val_loss: 2.2379 - val_accuracy: 0.7689 - val_precision: 0.7719 - val_recall: 0.7689 - val_sensitivity_at_specificity: 0.8693 - val_specificity_at_sensitivity: 0.9803
# Epoch 28/50
# 105/105 [==============================] - 55s 526ms/step - loss: 5.9776e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - sensitivity_at_specificity: 1.0000 - specificity_at_sensitivity: 1.0000 - val_loss: 2.2703 - val_accuracy: 0.7670 - val_precision: 0.7685 - val_recall: 0.7670 - val_sensitivity_at_specificity: 0.8674 - val_specificity_at_sensitivity: 0.9799
# Epoch 29/50
# 105/105 [==============================] - 55s 520ms/step - loss: 5.1279e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - sensitivity_at_specificity: 1.0000 - specificity_at_sensitivity: 1.0000 - val_loss: 2.2985 - val_accuracy: 0.7670 - val_precision: 0.7670 - val_recall: 0.7670 - val_sensitivity_at_specificity: 0.8674 - val_specificity_at_sensitivity: 0.9799
# Epoch 30/50
# 105/105 [==============================] - 55s 521ms/step - loss: 4.4534e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - sensitivity_at_specificity: 1.0000 - specificity_at_sensitivity: 1.0000 - val_loss: 2.3245 - val_accuracy: 0.7670 - val_precision: 0.7685 - val_recall: 0.7670 - val_sensitivity_at_specificity: 0.8674 - val_specificity_at_sensitivity: 0.9799
# Epoch 31/50
# 105/105 [==============================] - 55s 522ms/step - loss: 3.9046e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - sensitivity_at_specificity: 1.0000 - specificity_at_sensitivity: 1.0000 - val_loss: 2.3510 - val_accuracy: 0.7670 - val_precision: 0.7670 - val_recall: 0.7670 - val_sensitivity_at_specificity: 0.8655 - val_specificity_at_sensitivity: 0.9795
# Epoch 32/50
# 105/105 [==============================] - 54s 515ms/step - loss: 3.4530e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - sensitivity_at_specificity: 1.0000 - specificity_at_sensitivity: 1.0000 - val_loss: 2.3735 - val_accuracy: 0.7652 - val_precision: 0.7652 - val_recall: 0.7652 - val_sensitivity_at_specificity: 0.8598 - val_specificity_at_sensitivity: 0.9784
# Epoch 33/50
# 105/105 [==============================] - 56s 535ms/step - loss: 3.0801e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - sensitivity_at_specificity: 1.0000 - specificity_at_sensitivity: 1.0000 - val_loss: 2.3975 - val_accuracy: 0.7652 - val_precision: 0.7652 - val_recall: 0.7652 - val_sensitivity_at_specificity: 0.8561 - val_specificity_at_sensitivity: 0.9780
# Epoch 34/50
# 105/105 [==============================] - 79s 750ms/step - loss: 2.7506e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - sensitivity_at_specificity: 1.0000 - specificity_at_sensitivity: 1.0000 - val_loss: 2.4190 - val_accuracy: 0.7670 - val_precision: 0.7670 - val_recall: 0.7670 - val_sensitivity_at_specificity: 0.8561 - val_specificity_at_sensitivity: 0.9780
# Epoch 35/50
# 105/105 [==============================] - 59s 556ms/step - loss: 2.4734e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - sensitivity_at_specificity: 1.0000 - specificity_at_sensitivity: 1.0000 - val_loss: 2.4392 - val_accuracy: 0.7670 - val_precision: 0.7670 - val_recall: 0.7670 - val_sensitivity_at_specificity: 0.8561 - val_specificity_at_sensitivity: 0.9780
# Epoch 36/50
# 105/105 [==============================] - 55s 520ms/step - loss: 2.2357e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - sensitivity_at_specificity: 1.0000 - specificity_at_sensitivity: 1.0000 - val_loss: 2.4599 - val_accuracy: 0.7670 - val_precision: 0.7670 - val_recall: 0.7670 - val_sensitivity_at_specificity: 0.8561 - val_specificity_at_sensitivity: 0.9773
# Epoch 37/50
# 105/105 [==============================] - 54s 516ms/step - loss: 2.0231e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - sensitivity_at_specificity: 1.0000 - specificity_at_sensitivity: 1.0000 - val_loss: 2.4782 - val_accuracy: 0.7670 - val_precision: 0.7670 - val_recall: 0.7670 - val_sensitivity_at_specificity: 0.8561 - val_specificity_at_sensitivity: 0.9773
# Epoch 38/50
# 105/105 [==============================] - 55s 526ms/step - loss: 1.8375e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - sensitivity_at_specificity: 1.0000 - specificity_at_sensitivity: 1.0000 - val_loss: 2.4979 - val_accuracy: 0.7670 - val_precision: 0.7670 - val_recall: 0.7670 - val_sensitivity_at_specificity: 0.8561 - val_specificity_at_sensitivity: 0.9773
# Epoch 39/50
# 105/105 [==============================] - 55s 520ms/step - loss: 1.6755e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - sensitivity_at_specificity: 1.0000 - specificity_at_sensitivity: 1.0000 - val_loss: 2.5172 - val_accuracy: 0.7670 - val_precision: 0.7670 - val_recall: 0.7670 - val_sensitivity_at_specificity: 0.8561 - val_specificity_at_sensitivity: 0.9769
# Epoch 40/50
# 105/105 [==============================] - 55s 522ms/step - loss: 1.5342e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - sensitivity_at_specificity: 1.0000 - specificity_at_sensitivity: 1.0000 - val_loss: 2.5347 - val_accuracy: 0.7670 - val_precision: 0.7670 - val_recall: 0.7670 - val_sensitivity_at_specificity: 0.8542 - val_specificity_at_sensitivity: 0.9765
# Epoch 41/50
# 105/105 [==============================] - 55s 523ms/step - loss: 1.4044e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - sensitivity_at_specificity: 1.0000 - specificity_at_sensitivity: 1.0000 - val_loss: 2.5528 - val_accuracy: 0.7670 - val_precision: 0.7670 - val_recall: 0.7670 - val_sensitivity_at_specificity: 0.8523 - val_specificity_at_sensitivity: 0.9761
# Epoch 42/50
# 105/105 [==============================] - 55s 520ms/step - loss: 1.2935e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - sensitivity_at_specificity: 1.0000 - specificity_at_sensitivity: 1.0000 - val_loss: 2.5696 - val_accuracy: 0.7670 - val_precision: 0.7670 - val_recall: 0.7670 - val_sensitivity_at_specificity: 0.8504 - val_specificity_at_sensitivity: 0.9758
# Epoch 43/50
# 105/105 [==============================] - 55s 523ms/step - loss: 1.1893e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - sensitivity_at_specificity: 1.0000 - specificity_at_sensitivity: 1.0000 - val_loss: 2.5861 - val_accuracy: 0.7670 - val_precision: 0.7670 - val_recall: 0.7670 - val_sensitivity_at_specificity: 0.8504 - val_specificity_at_sensitivity: 0.9758
# Epoch 44/50
# 105/105 [==============================] - 54s 517ms/step - loss: 1.0968e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - sensitivity_at_specificity: 1.0000 - specificity_at_sensitivity: 1.0000 - val_loss: 2.6026 - val_accuracy: 0.7670 - val_precision: 0.7670 - val_recall: 0.7670 - val_sensitivity_at_specificity: 0.8504 - val_specificity_at_sensitivity: 0.9758
# Epoch 45/50
# 105/105 [==============================] - 55s 520ms/step - loss: 1.0115e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - sensitivity_at_specificity: 1.0000 - specificity_at_sensitivity: 1.0000 - val_loss: 2.6193 - val_accuracy: 0.7652 - val_precision: 0.7652 - val_recall: 0.7652 - val_sensitivity_at_specificity: 0.8485 - val_specificity_at_sensitivity: 0.9758
# Epoch 46/50
# 105/105 [==============================] - 55s 518ms/step - loss: 9.3497e-06 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - sensitivity_at_specificity: 1.0000 - specificity_at_sensitivity: 1.0000 - val_loss: 2.6354 - val_accuracy: 0.7652 - val_precision: 0.7652 - val_recall: 0.7652 - val_sensitivity_at_specificity: 0.8485 - val_specificity_at_sensitivity: 0.9758
# Epoch 47/50
# 105/105 [==============================] - 55s 521ms/step - loss: 8.6063e-06 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - sensitivity_at_specificity: 1.0000 - specificity_at_sensitivity: 1.0000 - val_loss: 2.6496 - val_accuracy: 0.7652 - val_precision: 0.7652 - val_recall: 0.7652 - val_sensitivity_at_specificity: 0.8485 - val_specificity_at_sensitivity: 0.9754
# Epoch 48/50
# 105/105 [==============================] - 55s 518ms/step - loss: 7.9703e-06 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - sensitivity_at_specificity: 1.0000 - specificity_at_sensitivity: 1.0000 - val_loss: 2.6646 - val_accuracy: 0.7633 - val_precision: 0.7633 - val_recall: 0.7633 - val_sensitivity_at_specificity: 0.8485 - val_specificity_at_sensitivity: 0.9754
# Epoch 49/50
# 105/105 [==============================] - 55s 523ms/step - loss: 7.3994e-06 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - sensitivity_at_specificity: 1.0000 - specificity_at_sensitivity: 1.0000 - val_loss: 2.6836 - val_accuracy: 0.7633 - val_precision: 0.7633 - val_recall: 0.7633 - val_sensitivity_at_specificity: 0.8485 - val_specificity_at_sensitivity: 0.9754
# Epoch 50/50
# 105/105 [==============================] - 55s 527ms/step - loss: 6.8481e-06 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - sensitivity_at_specificity: 1.0000 - specificity_at_sensitivity: 1.0000 - val_loss: 2.6963 - val_accuracy: 0.7633 - val_precision: 0.7633 - val_recall: 0.7633 - val_sensitivity_at_specificity: 0.8485 - val_specificity_at_sensitivity: 0.9754

# %%
fig, ax = plt.subplots(2,1)
ax[0].plot(hist.history['accuracy'], color='b', label="Training accuracy")
ax[0].plot(hist.history['val_accuracy'], color='r',label="Validation accuracy")
legend = ax[0].legend(loc='best', shadow=True)

ax[1].plot(hist.history['loss'], color='b', label="Training loss")
ax[1].plot(hist.history['val_loss'], color='r', label="validation loss")
legend = ax[1].legend(loc='best', shadow=True)

# %%
fig, ax = plt.subplots(2,1)
ax[0].plot(hist.history['precision'], color='b', label="Training precision")
ax[0].plot(hist.history['val_precision'], color='r',label="Validation precision")
legend = ax[0].legend(loc='best', shadow=True)

ax[1].plot(hist.history['loss'], color='b', label="Training loss")
ax[1].plot(hist.history['val_loss'], color='r', label="validation loss")
legend = ax[1].legend(loc='best', shadow=True)

# %%
fig, ax = plt.subplots(2,1)
ax[0].plot(hist.history['recall'], color='b', label="Training recall")
ax[0].plot(hist.history['val_recall'], color='r',label="Validation recall")
legend = ax[0].legend(loc='best', shadow=True)

ax[1].plot(hist.history['loss'], color='b', label="Training loss")
ax[1].plot(hist.history['val_loss'], color='r', label="validation loss")
legend = ax[1].legend(loc='best', shadow=True)

# %%
fig, ax = plt.subplots(2,1)
ax[0].plot(hist.history['sensitivity_at_specificity'], color='b', label="Training sensitivity")
ax[0].plot(hist.history['val_sensitivity_at_specificity'], color='r',label="Validation sensitivity")
legend = ax[0].legend(loc='best', shadow=True)

ax[1].plot(hist.history['loss'], color='b', label="Training loss")
ax[1].plot(hist.history['val_loss'], color='r', label="validation loss")
legend = ax[1].legend(loc='best', shadow=True)

# %%
fig, ax = plt.subplots(2,1)
ax[0].plot(hist.history['specificity_at_sensitivity'], color='b', label="Training specificity")
ax[0].plot(hist.history['val_specificity_at_sensitivity'], color='r',label="Validation specificity")
legend = ax[0].legend(loc='best', shadow=True)

ax[1].plot(hist.history['loss'], color='b', label="Training loss")
ax[1].plot(hist.history['val_loss'], color='r', label="validation loss")
legend = ax[1].legend(loc='best', shadow=True)

# %%
model.save("./models/CNN.h5")

# %%
filenames = test_generator.filenames
nb_samples = len(filenames)
model_predict = model.predict_generator(test_generator,steps = nb_samples, verbose=2)
# Out:
# c:\Users\0258\.conda\envs\deepfake\lib\site-packages\keras\engine\training.py:2035: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   warnings.warn('`Model.predict_generator` is deprecated and '
# WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 528 batches). You may need to use the repeat() function when building your dataset.
# 528/528 - 10s

# %%
y_true = test_generator.classes
y_pred = model_predict.argmax(axis=1)
plot_confusion_matrix(y_true, y_pred, classes=['Bacterial_leaf_blight', 'Brown_spot','Healthy','Leaf_blast','Leaf_scald','Narrow_brown_spot'],
                      title='Confusion matrix')
# Out:
# Confusion matrix, without normalization
# [[14 21 14 12 14 13]
#  [14 14 11 13 18 18]
#  [14  9 21 17 10 17]
#  [19  8 11 14 18 18]
#  [13 10 14 14 20 17]
#  [17 19 16 10 14 12]]
# <AxesSubplot:title={'center':'Confusion matrix'}, xlabel='Predicted label', ylabel='True label'>

# %% [markdown]
# ## VGG16

# %%
base_model1 =tf.keras.applications.VGG16(input_shape=(img_height,img_width, 3), include_top=False,
                          weights='imagenet')
model1 = Sequential()
model1.add(base_model1)
model1.add(GlobalAveragePooling2D())
model1.add(Dense(1024, activation='relu'))
model1.add(Dense(512, activation='relu'))
model1.add(Dense(256, activation='relu'))
model1.add(Dense(128, activation='relu'))
model1.add(Dense(64, activation='relu'))
model1.add(BatchNormalization())
model1.add(Dropout(0.2))
model1.add(Dense(6, activation='sigmoid'))
model1.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# vgg16 (Functional)           (None, 8, 8, 512)         14714688
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1024)              525312
# _________________________________________________________________
# dense_3 (Dense)              (None, 512)               524800
# _________________________________________________________________
# dense_4 (Dense)              (None, 256)               131328
# _________________________________________________________________
# dense_5 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dense_6 (Dense)              (None, 64)                8256
# _________________________________________________________________
# batch_normalization (BatchNo (None, 64)                256
# _________________________________________________________________
# dropout (Dropout)            (None, 64)                0
# _________________________________________________________________
# dense_7 (Dense)              (None, 6)                 390
# =================================================================
# Total params: 15,937,926
# Trainable params: 15,937,798
# Non-trainable params: 128
# _________________________________________________________________

# %%
model1.compile(optimizer="adam",loss="categorical_crossentropy",metrics=['accuracy',precision,recall,sensitivity,specificity])
hist1=model1.fit(train_generator,epochs=50,validation_data=test_generator)
model1.save("./models/vgg16.h5")
# Out:
# Epoch 1/50
# 105/105 [==============================] - 67s 547ms/step - loss: 1.6471 - accuracy: 0.2790 - precision: 0.2669 - recall: 0.7199 - sensitivity_at_specificity: 0.9692 - specificity_at_sensitivity: 0.9947 - val_loss: 5.3610 - val_accuracy: 0.1667 - val_precision: 0.1667 - val_recall: 0.5000 - val_sensitivity_at_specificity: 0.8712 - val_specificity_at_sensitivity: 0.8958
# Epoch 2/50
# 105/105 [==============================] - 55s 520ms/step - loss: 1.4341 - accuracy: 0.3519 - precision: 0.2516 - recall: 0.8576 - sensitivity_at_specificity: 0.9986 - specificity_at_sensitivity: 0.9878 - val_loss: 13.9984 - val_accuracy: 0.1723 - val_precision: 0.1581 - val_recall: 0.5000 - val_sensitivity_at_specificity: 0.9830 - val_specificity_at_sensitivity: 0.5155
# Epoch 3/50
# 105/105 [==============================] - 56s 529ms/step - loss: 1.4042 - accuracy: 0.3900 - precision: 0.2533 - recall: 0.8995 - sensitivity_at_specificity: 0.9986 - specificity_at_sensitivity: 0.9865 - val_loss: 5.1374 - val_accuracy: 0.1667 - val_precision: 0.1822 - val_recall: 0.7045 - val_sensitivity_at_specificity: 0.9697 - val_specificity_at_sensitivity: 0.7587
# Epoch 4/50
# 105/105 [==============================] - 58s 548ms/step - loss: 1.3233 - accuracy: 0.4086 - precision: 0.2598 - recall: 0.9262 - sensitivity_at_specificity: 0.9990 - specificity_at_sensitivity: 0.9870 - val_loss: 13.1674 - val_accuracy: 0.1667 - val_precision: 0.1667 - val_recall: 0.5000 - val_sensitivity_at_specificity: 0.6667 - val_specificity_at_sensitivity: 0.6667
# Epoch 5/50
# 105/105 [==============================] - 59s 559ms/step - loss: 1.2706 - accuracy: 0.4410 - precision: 0.2629 - recall: 0.9376 - sensitivity_at_specificity: 1.0000 - specificity_at_sensitivity: 0.9935 - val_loss: 18.5869 - val_accuracy: 0.1667 - val_precision: 0.1667 - val_recall: 0.5000 - val_sensitivity_at_specificity: 0.6667 - val_specificity_at_sensitivity: 0.5235
# Epoch 6/50
# 105/105 [==============================] - 59s 559ms/step - loss: 1.2404 - accuracy: 0.4624 - precision: 0.2680 - recall: 0.9338 - sensitivity_at_specificity: 0.9995 - specificity_at_sensitivity: 0.9941 - val_loss: 15.5774 - val_accuracy: 0.1667 - val_precision: 0.1667 - val_recall: 0.5000 - val_sensitivity_at_specificity: 0.5511 - val_specificity_at_sensitivity: 0.5345
# Epoch 7/50
# 105/105 [==============================] - 59s 565ms/step - loss: 1.2001 - accuracy: 0.4881 - precision: 0.2736 - recall: 0.9524 - sensitivity_at_specificity: 0.9990 - specificity_at_sensitivity: 0.9937 - val_loss: 2.6241 - val_accuracy: 0.2367 - val_precision: 0.2372 - val_recall: 0.8864 - val_sensitivity_at_specificity: 1.0000 - val_specificity_at_sensitivity: 0.8845
# Epoch 8/50
# 105/105 [==============================] - 60s 568ms/step - loss: 1.2123 - accuracy: 0.4776 - precision: 0.2711 - recall: 0.9514 - sensitivity_at_specificity: 0.9995 - specificity_at_sensitivity: 0.9917 - val_loss: 12.6943 - val_accuracy: 0.1667 - val_precision: 0.1790 - val_recall: 0.6212 - val_sensitivity_at_specificity: 0.8333 - val_specificity_at_sensitivity: 0.5000
# Epoch 9/50
# 105/105 [==============================] - 61s 580ms/step - loss: 1.2136 - accuracy: 0.4695 - precision: 0.2745 - recall: 0.9510 - sensitivity_at_specificity: 0.9995 - specificity_at_sensitivity: 0.9907 - val_loss: 12.6606 - val_accuracy: 0.1667 - val_precision: 0.1667 - val_recall: 0.5000 - val_sensitivity_at_specificity: 0.7083 - val_specificity_at_sensitivity: 0.6697
# Epoch 10/50
# 105/105 [==============================] - 73s 695ms/step - loss: 1.1937 - accuracy: 0.4652 - precision: 0.2761 - recall: 0.9457 - sensitivity_at_specificity: 1.0000 - specificity_at_sensitivity: 0.9881 - val_loss: 56.4659 - val_accuracy: 0.1667 - val_precision: 0.1667 - val_recall: 0.6667 - val_sensitivity_at_specificity: 0.9223 - val_specificity_at_sensitivity: 0.3333
# Epoch 11/50
# 105/105 [==============================] - 76s 722ms/step - loss: 1.1815 - accuracy: 0.4567 - precision: 0.2708 - recall: 0.9552 - sensitivity_at_specificity: 1.0000 - specificity_at_sensitivity: 0.9901 - val_loss: 1.2658 - val_accuracy: 0.5000 - val_precision: 0.2061 - val_recall: 0.9981 - val_sensitivity_at_specificity: 1.0000 - val_specificity_at_sensitivity: 0.9818
# Epoch 12/50
# 105/105 [==============================] - 62s 584ms/step - loss: 1.1351 - accuracy: 0.4829 - precision: 0.2774 - recall: 0.9529 - sensitivity_at_specificity: 1.0000 - specificity_at_sensitivity: 0.9875 - val_loss: 3.6660 - val_accuracy: 0.1780 - val_precision: 0.1986 - val_recall: 0.8239 - val_sensitivity_at_specificity: 0.9735 - val_specificity_at_sensitivity: 0.8023
# Epoch 13/50
# 105/105 [==============================] - 62s 585ms/step - loss: 1.1453 - accuracy: 0.4824 - precision: 0.2734 - recall: 0.9552 - sensitivity_at_specificity: 1.0000 - specificity_at_sensitivity: 0.9862 - val_loss: 2.2545 - val_accuracy: 0.2348 - val_precision: 0.2324 - val_recall: 0.8106 - val_sensitivity_at_specificity: 1.0000 - val_specificity_at_sensitivity: 0.9875
# Epoch 14/50
# 105/105 [==============================] - 63s 600ms/step - loss: 1.1396 - accuracy: 0.4762 - precision: 0.2721 - recall: 0.9567 - sensitivity_at_specificity: 0.9995 - specificity_at_sensitivity: 0.9851 - val_loss: 12.9584 - val_accuracy: 0.1686 - val_precision: 0.1654 - val_recall: 0.5019 - val_sensitivity_at_specificity: 0.7595 - val_specificity_at_sensitivity: 0.7330
# Epoch 15/50
# 105/105 [==============================] - 62s 591ms/step - loss: 1.1382 - accuracy: 0.4900 - precision: 0.2767 - recall: 0.9533 - sensitivity_at_specificity: 1.0000 - specificity_at_sensitivity: 0.9841 - val_loss: 26.0854 - val_accuracy: 0.1667 - val_precision: 0.1667 - val_recall: 0.5000 - val_sensitivity_at_specificity: 0.5000 - val_specificity_at_sensitivity: 0.6667
# Epoch 16/50
# 105/105 [==============================] - 63s 597ms/step - loss: 1.1121 - accuracy: 0.5219 - precision: 0.2760 - recall: 0.9543 - sensitivity_at_specificity: 0.9990 - specificity_at_sensitivity: 0.9841 - val_loss: 29.6108 - val_accuracy: 0.1667 - val_precision: 0.1667 - val_recall: 0.5000 - val_sensitivity_at_specificity: 0.5000 - val_specificity_at_sensitivity: 0.6689
# Epoch 17/50
# 105/105 [==============================] - 62s 592ms/step - loss: 1.1039 - accuracy: 0.5071 - precision: 0.2773 - recall: 0.9686 - sensitivity_at_specificity: 1.0000 - specificity_at_sensitivity: 0.9931 - val_loss: 18.9999 - val_accuracy: 0.1667 - val_precision: 0.1667 - val_recall: 0.5000 - val_sensitivity_at_specificity: 0.6686 - val_specificity_at_sensitivity: 0.6333
# Epoch 18/50
# 105/105 [==============================] - 62s 593ms/step - loss: 1.0745 - accuracy: 0.5181 - precision: 0.2775 - recall: 0.9790 - sensitivity_at_specificity: 1.0000 - specificity_at_sensitivity: 0.9893 - val_loss: 4.3026 - val_accuracy: 0.2689 - val_precision: 0.2296 - val_recall: 0.6723 - val_sensitivity_at_specificity: 1.0000 - val_specificity_at_sensitivity: 0.9117
# Epoch 19/50
# 105/105 [==============================] - 62s 590ms/step - loss: 1.0675 - accuracy: 0.5305 - precision: 0.2842 - recall: 0.9733 - sensitivity_at_specificity: 0.9995 - specificity_at_sensitivity: 0.9920 - val_loss: 24.1637 - val_accuracy: 0.1667 - val_precision: 0.1667 - val_recall: 0.5000 - val_sensitivity_at_specificity: 0.5000 - val_specificity_at_sensitivity: 0.6667
# Epoch 20/50
# 105/105 [==============================] - 62s 589ms/step - loss: 1.0587 - accuracy: 0.5110 - precision: 0.2890 - recall: 0.9714 - sensitivity_at_specificity: 1.0000 - specificity_at_sensitivity: 0.9902 - val_loss: 5.6064 - val_accuracy: 0.1667 - val_precision: 0.1666 - val_recall: 0.5000 - val_sensitivity_at_specificity: 0.9811 - val_specificity_at_sensitivity: 0.8814
# Epoch 21/50
# 105/105 [==============================] - 62s 590ms/step - loss: 1.1375 - accuracy: 0.4971 - precision: 0.2846 - recall: 0.9595 - sensitivity_at_specificity: 0.9990 - specificity_at_sensitivity: 0.9801 - val_loss: 94.2515 - val_accuracy: 0.1667 - val_precision: 0.1667 - val_recall: 0.3333 - val_sensitivity_at_specificity: 0.8333 - val_specificity_at_sensitivity: 0.6667
# Epoch 22/50
# 105/105 [==============================] - 62s 589ms/step - loss: 1.2368 - accuracy: 0.4643 - precision: 0.2758 - recall: 0.9376 - sensitivity_at_specificity: 0.9990 - specificity_at_sensitivity: 0.9740 - val_loss: 92.7558 - val_accuracy: 0.1667 - val_precision: 0.1667 - val_recall: 0.3333 - val_sensitivity_at_specificity: 0.8333 - val_specificity_at_sensitivity: 0.6667
# Epoch 23/50
# 105/105 [==============================] - 63s 595ms/step - loss: 1.1430 - accuracy: 0.4690 - precision: 0.2772 - recall: 0.9600 - sensitivity_at_specificity: 1.0000 - specificity_at_sensitivity: 0.9806 - val_loss: 5.3775 - val_accuracy: 0.1667 - val_precision: 0.1667 - val_recall: 0.5000 - val_sensitivity_at_specificity: 0.8466 - val_specificity_at_sensitivity: 0.8852
# Epoch 24/50
# 105/105 [==============================] - 64s 606ms/step - loss: 1.0810 - accuracy: 0.5195 - precision: 0.2795 - recall: 0.9624 - sensitivity_at_specificity: 1.0000 - specificity_at_sensitivity: 0.9826 - val_loss: 1.1331 - val_accuracy: 0.4508 - val_precision: 0.3317 - val_recall: 0.8731 - val_sensitivity_at_specificity: 1.0000 - val_specificity_at_sensitivity: 0.9841
# Epoch 25/50
# 105/105 [==============================] - 61s 580ms/step - loss: 1.1032 - accuracy: 0.5133 - precision: 0.2792 - recall: 0.9614 - sensitivity_at_specificity: 1.0000 - specificity_at_sensitivity: 0.9806 - val_loss: 6.4612 - val_accuracy: 0.1667 - val_precision: 0.1748 - val_recall: 0.5000 - val_sensitivity_at_specificity: 0.9299 - val_specificity_at_sensitivity: 0.8591
# Epoch 26/50
# 105/105 [==============================] - 62s 588ms/step - loss: 1.1352 - accuracy: 0.4933 - precision: 0.2758 - recall: 0.9590 - sensitivity_at_specificity: 1.0000 - specificity_at_sensitivity: 0.9782 - val_loss: 7.7304 - val_accuracy: 0.1667 - val_precision: 0.1741 - val_recall: 0.4962 - val_sensitivity_at_specificity: 0.8807 - val_specificity_at_sensitivity: 0.7280
# Epoch 27/50
# 105/105 [==============================] - 61s 582ms/step - loss: 1.1180 - accuracy: 0.4986 - precision: 0.2784 - recall: 0.9652 - sensitivity_at_specificity: 1.0000 - specificity_at_sensitivity: 0.9830 - val_loss: 45.1779 - val_accuracy: 0.1667 - val_precision: 0.1667 - val_recall: 0.5000 - val_sensitivity_at_specificity: 0.5000 - val_specificity_at_sensitivity: 0.5049
# Epoch 28/50
# 105/105 [==============================] - 63s 595ms/step - loss: 1.1113 - accuracy: 0.5152 - precision: 0.2681 - recall: 0.9657 - sensitivity_at_specificity: 1.0000 - specificity_at_sensitivity: 0.9917 - val_loss: 28.5499 - val_accuracy: 0.1667 - val_precision: 0.1667 - val_recall: 0.5000 - val_sensitivity_at_specificity: 0.6326 - val_specificity_at_sensitivity: 0.5000
# Epoch 29/50
# 105/105 [==============================] - 63s 596ms/step - loss: 1.0847 - accuracy: 0.5238 - precision: 0.2723 - recall: 0.9652 - sensitivity_at_specificity: 1.0000 - specificity_at_sensitivity: 0.9922 - val_loss: 9.0436 - val_accuracy: 0.1667 - val_precision: 0.1679 - val_recall: 0.5000 - val_sensitivity_at_specificity: 0.8163 - val_specificity_at_sensitivity: 0.5902
# Epoch 30/50
# 105/105 [==============================] - 62s 589ms/step - loss: 1.0991 - accuracy: 0.5267 - precision: 0.2755 - recall: 0.9676 - sensitivity_at_specificity: 1.0000 - specificity_at_sensitivity: 0.9940 - val_loss: 48.8584 - val_accuracy: 0.1667 - val_precision: 0.1667 - val_recall: 0.5000 - val_sensitivity_at_specificity: 0.5000 - val_specificity_at_sensitivity: 0.5000
# Epoch 31/50
# 105/105 [==============================] - 68s 646ms/step - loss: 1.1116 - accuracy: 0.5038 - precision: 0.2614 - recall: 0.9671 - sensitivity_at_specificity: 1.0000 - specificity_at_sensitivity: 0.9950 - val_loss: 9.7278 - val_accuracy: 0.1667 - val_precision: 0.1963 - val_recall: 0.7936 - val_sensitivity_at_specificity: 0.9886 - val_specificity_at_sensitivity: 0.4992
# Epoch 32/50
# 105/105 [==============================] - 65s 613ms/step - loss: 1.0541 - accuracy: 0.5448 - precision: 0.2732 - recall: 0.9662 - sensitivity_at_specificity: 1.0000 - specificity_at_sensitivity: 0.9927 - val_loss: 17.8180 - val_accuracy: 0.1667 - val_precision: 0.1667 - val_recall: 0.5000 - val_sensitivity_at_specificity: 0.7784 - val_specificity_at_sensitivity: 0.5011
# Epoch 33/50
# 105/105 [==============================] - 65s 618ms/step - loss: 1.0494 - accuracy: 0.5314 - precision: 0.2863 - recall: 0.9690 - sensitivity_at_specificity: 1.0000 - specificity_at_sensitivity: 0.9871 - val_loss: 39.8510 - val_accuracy: 0.1667 - val_precision: 0.1667 - val_recall: 0.5000 - val_sensitivity_at_specificity: 0.5000 - val_specificity_at_sensitivity: 0.5000
# Epoch 34/50
# 105/105 [==============================] - 65s 613ms/step - loss: 1.0489 - accuracy: 0.5119 - precision: 0.2889 - recall: 0.9710 - sensitivity_at_specificity: 1.0000 - specificity_at_sensitivity: 0.9854 - val_loss: 45.3803 - val_accuracy: 0.1667 - val_precision: 0.1667 - val_recall: 0.5000 - val_sensitivity_at_specificity: 0.5000 - val_specificity_at_sensitivity: 0.5000
# Epoch 35/50
# 105/105 [==============================] - 65s 621ms/step - loss: 1.0468 - accuracy: 0.5214 - precision: 0.2874 - recall: 0.9652 - sensitivity_at_specificity: 1.0000 - specificity_at_sensitivity: 0.9825 - val_loss: 14.0521 - val_accuracy: 0.1667 - val_precision: 0.1667 - val_recall: 0.5000 - val_sensitivity_at_specificity: 0.6818 - val_specificity_at_sensitivity: 0.7678
# Epoch 36/50
# 105/105 [==============================] - 65s 618ms/step - loss: 1.0438 - accuracy: 0.5119 - precision: 0.2925 - recall: 0.9695 - sensitivity_at_specificity: 1.0000 - specificity_at_sensitivity: 0.9800 - val_loss: 3.0280 - val_accuracy: 0.2936 - val_precision: 0.3250 - val_recall: 0.6174 - val_sensitivity_at_specificity: 0.8390 - val_specificity_at_sensitivity: 0.9428
# Epoch 37/50
# 105/105 [==============================] - 63s 596ms/step - loss: 1.0178 - accuracy: 0.5386 - precision: 0.2978 - recall: 0.9805 - sensitivity_at_specificity: 1.0000 - specificity_at_sensitivity: 0.9773 - val_loss: 1.9828 - val_accuracy: 0.3049 - val_precision: 0.2565 - val_recall: 0.8087 - val_sensitivity_at_specificity: 1.0000 - val_specificity_at_sensitivity: 0.9568
# Epoch 38/50
# 105/105 [==============================] - 70s 669ms/step - loss: 1.0866 - accuracy: 0.5024 - precision: 0.2875 - recall: 0.9624 - sensitivity_at_specificity: 1.0000 - specificity_at_sensitivity: 0.9751 - val_loss: 1.5502 - val_accuracy: 0.3769 - val_precision: 0.2316 - val_recall: 0.9924 - val_sensitivity_at_specificity: 1.0000 - val_specificity_at_sensitivity: 0.7367
# Epoch 39/50
# 105/105 [==============================] - 66s 626ms/step - loss: 0.9699 - accuracy: 0.5562 - precision: 0.2911 - recall: 0.9762 - sensitivity_at_specificity: 1.0000 - specificity_at_sensitivity: 0.9689 - val_loss: 10.8024 - val_accuracy: 0.0492 - val_precision: 0.1818 - val_recall: 0.8333 - val_sensitivity_at_specificity: 0.8333 - val_specificity_at_sensitivity: 0.4977
# Epoch 40/50
# 105/105 [==============================] - 66s 625ms/step - loss: 1.0079 - accuracy: 0.5429 - precision: 0.2934 - recall: 0.9738 - sensitivity_at_specificity: 1.0000 - specificity_at_sensitivity: 0.9612 - val_loss: 61.6630 - val_accuracy: 0.1667 - val_precision: 0.1667 - val_recall: 0.5000 - val_sensitivity_at_specificity: 0.8333 - val_specificity_at_sensitivity: 0.5000
# Epoch 41/50
# 105/105 [==============================] - 65s 613ms/step - loss: 0.9821 - accuracy: 0.5500 - precision: 0.2927 - recall: 0.9810 - sensitivity_at_specificity: 0.9995 - specificity_at_sensitivity: 0.9595 - val_loss: 29.0411 - val_accuracy: 0.1667 - val_precision: 0.1667 - val_recall: 0.5000 - val_sensitivity_at_specificity: 0.5000 - val_specificity_at_sensitivity: 0.5000
# Epoch 42/50
# 105/105 [==============================] - 67s 635ms/step - loss: 0.9468 - accuracy: 0.5729 - precision: 0.2926 - recall: 0.9819 - sensitivity_at_specificity: 0.9995 - specificity_at_sensitivity: 0.9658 - val_loss: 9.9275 - val_accuracy: 0.1667 - val_precision: 0.1678 - val_recall: 0.5000 - val_sensitivity_at_specificity: 0.7008 - val_specificity_at_sensitivity: 0.7068
# Epoch 43/50
# 105/105 [==============================] - 65s 614ms/step - loss: 0.9350 - accuracy: 0.5790 - precision: 0.2927 - recall: 0.9848 - sensitivity_at_specificity: 1.0000 - specificity_at_sensitivity: 0.9649 - val_loss: 10.7552 - val_accuracy: 0.1667 - val_precision: 0.1502 - val_recall: 0.5000 - val_sensitivity_at_specificity: 0.8674 - val_specificity_at_sensitivity: 0.5564
# Epoch 44/50
# 105/105 [==============================] - 64s 612ms/step - loss: 0.9749 - accuracy: 0.5510 - precision: 0.2914 - recall: 0.9776 - sensitivity_at_specificity: 1.0000 - specificity_at_sensitivity: 0.9615 - val_loss: 23.4534 - val_accuracy: 0.1667 - val_precision: 0.1667 - val_recall: 0.5000 - val_sensitivity_at_specificity: 0.5966 - val_specificity_at_sensitivity: 0.5178
# Epoch 45/50
# 105/105 [==============================] - 66s 630ms/step - loss: 0.9551 - accuracy: 0.5619 - precision: 0.2939 - recall: 0.9819 - sensitivity_at_specificity: 1.0000 - specificity_at_sensitivity: 0.9576 - val_loss: 7.3265 - val_accuracy: 0.1780 - val_precision: 0.2015 - val_recall: 0.6629 - val_sensitivity_at_specificity: 0.9508 - val_specificity_at_sensitivity: 0.7576
# Epoch 46/50
# 105/105 [==============================] - 63s 597ms/step - loss: 1.0642 - accuracy: 0.5195 - precision: 0.2894 - recall: 0.9729 - sensitivity_at_specificity: 0.9995 - specificity_at_sensitivity: 0.9564 - val_loss: 16.4894 - val_accuracy: 0.1667 - val_precision: 0.1667 - val_recall: 0.5000 - val_sensitivity_at_specificity: 0.6705 - val_specificity_at_sensitivity: 0.6417
# Epoch 47/50
# 105/105 [==============================] - 65s 615ms/step - loss: 0.9298 - accuracy: 0.5829 - precision: 0.2906 - recall: 0.9800 - sensitivity_at_specificity: 1.0000 - specificity_at_sensitivity: 0.9576 - val_loss: 20.4343 - val_accuracy: 0.1667 - val_precision: 0.1667 - val_recall: 0.5000 - val_sensitivity_at_specificity: 0.5436 - val_specificity_at_sensitivity: 0.6208
# Epoch 48/50
# 105/105 [==============================] - 65s 619ms/step - loss: 0.9343 - accuracy: 0.5905 - precision: 0.2921 - recall: 0.9852 - sensitivity_at_specificity: 1.0000 - specificity_at_sensitivity: 0.9536 - val_loss: 7.4913 - val_accuracy: 0.1705 - val_precision: 0.1761 - val_recall: 0.5492 - val_sensitivity_at_specificity: 0.9602 - val_specificity_at_sensitivity: 0.7773
# Epoch 49/50
# 105/105 [==============================] - 65s 617ms/step - loss: 0.9274 - accuracy: 0.5824 - precision: 0.2955 - recall: 0.9867 - sensitivity_at_specificity: 1.0000 - specificity_at_sensitivity: 0.9494 - val_loss: 3.9609 - val_accuracy: 0.1761 - val_precision: 0.1960 - val_recall: 0.6458 - val_sensitivity_at_specificity: 0.9943 - val_specificity_at_sensitivity: 0.8511
# Epoch 50/50
# 105/105 [==============================] - 64s 606ms/step - loss: 0.8992 - accuracy: 0.5919 - precision: 0.2929 - recall: 0.9843 - sensitivity_at_specificity: 1.0000 - specificity_at_sensitivity: 0.9443 - val_loss: 15.1839 - val_accuracy: 0.1667 - val_precision: 0.1667 - val_recall: 0.5000 - val_sensitivity_at_specificity: 0.6856 - val_specificity_at_sensitivity: 0.6110

# %%
fig, ax = plt.subplots(2,1)
ax[0].plot(hist1.history['accuracy'], color='b', label="Training accuracy")
ax[0].plot(hist1.history['val_accuracy'], color='r',label="Validation accuracy")
legend = ax[0].legend(loc='best', shadow=True)

ax[1].plot(hist1.history['loss'], color='b', label="Training loss")
ax[1].plot(hist1.history['val_loss'], color='r', label="validation loss")
legend = ax[1].legend(loc='best', shadow=True)

# %%
fig, ax = plt.subplots(2,1)
ax[0].plot(hist1.history['precision'], color='b', label="Training precision")
ax[0].plot(hist1.history['val_precision'], color='r',label="Validation precision")
legend = ax[0].legend(loc='best', shadow=True)

ax[1].plot(hist1.history['loss'], color='b', label="Training loss")
ax[1].plot(hist1.history['val_loss'], color='r', label="validation loss")
legend = ax[1].legend(loc='best', shadow=True)

# %%
fig, ax = plt.subplots(2,1)
ax[0].plot(hist1.history['recall'], color='b', label="Training recall")
ax[0].plot(hist1.history['val_recall'], color='r',label="Validation recall")
legend = ax[0].legend(loc='best', shadow=True)

ax[1].plot(hist1.history['loss'], color='b', label="Training loss")
ax[1].plot(hist1.history['val_loss'], color='r', label="validation loss")
legend = ax[1].legend(loc='best', shadow=True)

# %%
fig, ax = plt.subplots(2,1)
ax[0].plot(hist1.history['sensitivity_at_specificity'], color='b', label="Training sensitivity")
ax[0].plot(hist1.history['val_sensitivity_at_specificity'], color='r',label="Validation sensitivity")
legend = ax[0].legend(loc='best', shadow=True)

ax[1].plot(hist1.history['loss'], color='b', label="Training loss")
ax[1].plot(hist1.history['val_loss'], color='r', label="validation loss")
legend = ax[1].legend(loc='best', shadow=True)

# %%
fig, ax = plt.subplots(2,1)
ax[0].plot(hist1.history['specificity_at_sensitivity'], color='b', label="Training specificity")
ax[0].plot(hist1.history['val_specificity_at_sensitivity'], color='r',label="Validation specificity")
legend = ax[0].legend(loc='best', shadow=True)

ax[1].plot(hist1.history['loss'], color='b', label="Training loss")
ax[1].plot(hist1.history['val_loss'], color='r', label="validation loss")
legend = ax[1].legend(loc='best', shadow=True)

# %%
filenames = test_generator.filenames
nb_samples = len(filenames)
model1_predict = model1.predict_generator(test_generator,steps = nb_samples, verbose=2)
# Out:
# c:\Users\0258\.conda\envs\deepfake\lib\site-packages\keras\engine\training.py:2035: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   warnings.warn('`Model.predict_generator` is deprecated and '
# WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 528 batches). You may need to use the repeat() function when building your dataset.
# 528/528 - 12s

# %%
y_true = test_generator.classes
y_pred = model_predict.argmax(axis=1)
plot_confusion_matrix(y_true, y_pred, classes=['Bacterial_leaf_blight', 'Brown_spot','Healthy','Leaf_blast','Leaf_scald','Narrow_brown_spot'],
                      title='Confusion matrix')
# Out:
# Confusion matrix, without normalization
# [[14 21 14 12 14 13]
#  [14 14 11 13 18 18]
#  [14  9 21 17 10 17]
#  [19  8 11 14 18 18]
#  [13 10 14 14 20 17]
#  [17 19 16 10 14 12]]
# <AxesSubplot:title={'center':'Confusion matrix'}, xlabel='Predicted label', ylabel='True label'>

# %% [markdown]
# ## MOBILENET

# %%
base_model = tf.keras.applications.MobileNet(input_shape=(img_height,img_width, 3), include_top=False,
                          weights='imagenet')
model8 = Sequential()
model8.add(base_model)
model8.add(GlobalAveragePooling2D())
model8.add(Dense(1024, activation='relu'))
model8.add(Dense(512, activation='relu'))
model8.add(Dense(256, activation='relu'))
model8.add(Dense(128, activation='relu'))
model8.add(Dense(64, activation='relu'))
model8.add(BatchNormalization())
model8.add(Dropout(0.2))
model8.add(Dense(6, activation='sigmoid'))
model8.summary()
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# mobilenet_1.00_224 (Function (None, 8, 8, 1024)        3228864
# _________________________________________________________________
# global_average_pooling2d_1 ( (None, 1024)              0
# _________________________________________________________________
# dense_8 (Dense)              (None, 1024)              1049600
# _________________________________________________________________
# dense_9 (Dense)              (None, 512)               524800
# _________________________________________________________________
# dense_10 (Dense)             (None, 256)               131328
# _________________________________________________________________
# dense_11 (Dense)             (None, 128)               32896
# _________________________________________________________________
# dense_12 (Dense)             (None, 64)                8256
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 64)                256
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_13 (Dense)             (None, 6)                 390
# =================================================================
# Total params: 4,976,390
# Trainable params: 4,954,374
# Non-trainable params: 22,016
# _________________________________________________________________

# %%
model8.compile(optimizer="adam",loss="categorical_crossentropy",metrics=['accuracy',precision,recall,sensitivity,specificity])
hist8=model8.fit(train_generator,epochs=50,validation_data=test_generator)
model8.save("./models/mobilenet.h5")
# Out:
# Epoch 1/50
# 105/105 [==============================] - 71s 612ms/step - loss: 0.7343 - accuracy: 0.7438 - precision: 0.3227 - recall: 0.8463 - sensitivity_at_specificity: 0.9098 - specificity_at_sensitivity: 0.9217 - val_loss: 4.5772 - val_accuracy: 0.3845 - val_precision: 0.2303 - val_recall: 0.7576 - val_sensitivity_at_specificity: 0.9943 - val_specificity_at_sensitivity: 0.7712
# Epoch 2/50
# 105/105 [==============================] - 62s 587ms/step - loss: 0.3196 - accuracy: 0.8986 - precision: 0.4292 - recall: 0.9857 - sensitivity_at_specificity: 1.0000 - specificity_at_sensitivity: 0.9991 - val_loss: 0.9065 - val_accuracy: 0.7633 - val_precision: 0.3191 - val_recall: 0.9773 - val_sensitivity_at_specificity: 1.0000 - val_specificity_at_sensitivity: 0.9727
# Epoch 3/50
# 105/105 [==============================] - 61s 576ms/step - loss: 0.2871 - accuracy: 0.9052 - precision: 0.4442 - recall: 0.9862 - sensitivity_at_specificity: 1.0000 - specificity_at_sensitivity: 0.9991 - val_loss: 0.3593 - val_accuracy: 0.8693 - val_precision: 0.3855 - val_recall: 0.9848 - val_sensitivity_at_specificity: 1.0000 - val_specificity_at_sensitivity: 0.9848
# Epoch 4/50
# 105/105 [==============================] - 60s 568ms/step - loss: 0.1756 - accuracy: 0.9405 - precision: 0.4953 - recall: 0.9938 - sensitivity_at_specificity: 1.0000 - specificity_at_sensitivity: 0.9994 - val_loss: 2.1454 - val_accuracy: 0.6023 - val_precision: 0.3744 - val_recall: 0.8807 - val_sensitivity_at_specificity: 1.0000 - val_specificity_at_sensitivity: 0.9364
# Epoch 5/50
# 105/105 [==============================] - 59s 563ms/step - loss: 0.2083 - accuracy: 0.9343 - precision: 0.4814 - recall: 0.9957 - sensitivity_at_specificity: 1.0000 - specificity_at_sensitivity: 0.9987 - val_loss: 1.3919 - val_accuracy: 0.6686 - val_precision: 0.4124 - val_recall: 0.8958 - val_sensitivity_at_specificity: 1.0000 - val_specificity_at_sensitivity: 0.9758
# Epoch 6/50
# 105/105 [==============================] - 59s 561ms/step - loss: 0.1842 - accuracy: 0.9410 - precision: 0.4664 - recall: 0.9900 - sensitivity_at_specificity: 1.0000 - specificity_at_sensitivity: 0.9988 - val_loss: 0.5458 - val_accuracy: 0.8485 - val_precision: 0.4214 - val_recall: 0.9640 - val_sensitivity_at_specificity: 0.9943 - val_specificity_at_sensitivity: 0.9943
# Epoch 7/50
# 105/105 [==============================] - 58s 551ms/step - loss: 0.1541 - accuracy: 0.9490 - precision: 0.4986 - recall: 0.9952 - sensitivity_at_specificity: 1.0000 - specificity_at_sensitivity: 0.9992 - val_loss: 0.3329 - val_accuracy: 0.8769 - val_precision: 0.5034 - val_recall: 0.9886 - val_sensitivity_at_specificity: 1.0000 - val_specificity_at_sensitivity: 0.9989
# Epoch 8/50
# 105/105 [==============================] - 58s 553ms/step - loss: 0.1516 - accuracy: 0.9505 - precision: 0.5026 - recall: 0.9967 - sensitivity_at_specificity: 1.0000 - specificity_at_sensitivity: 0.9988 - val_loss: 0.1929 - val_accuracy: 0.9337 - val_precision: 0.4676 - val_recall: 0.9981 - val_sensitivity_at_specificity: 1.0000 - val_specificity_at_sensitivity: 0.9989
# Epoch 9/50
# 105/105 [==============================] - 58s 555ms/step - loss: 0.1486 - accuracy: 0.9529 - precision: 0.4969 - recall: 0.9957 - sensitivity_at_specificity: 1.0000 - specificity_at_sensitivity: 0.9988 - val_loss: 2.2213 - val_accuracy: 0.5511 - val_precision: 0.4671 - val_recall: 0.9413 - val_sensitivity_at_specificity: 1.0000 - val_specificity_at_sensitivity: 0.9186
# Epoch 10/50
# 105/105 [==============================] - 58s 549ms/step - loss: 0.0846 - accuracy: 0.9757 - precision: 0.5410 - recall: 0.9995 - sensitivity_at_specificity: 1.0000 - specificity_at_sensitivity: 0.9992 - val_loss: 0.1834 - val_accuracy: 0.9413 - val_precision: 0.4677 - val_recall: 1.0000 - val_sensitivity_at_specificity: 1.0000 - val_specificity_at_sensitivity: 0.9977
# Epoch 11/50
# 105/105 [==============================] - 57s 543ms/step - loss: 0.0983 - accuracy: 0.9729 - precision: 0.5198 - recall: 0.9957 - sensitivity_at_specificity: 1.0000 - specificity_at_sensitivity: 0.9992 - val_loss: 0.3006 - val_accuracy: 0.9167 - val_precision: 0.4415 - val_recall: 0.9867 - val_sensitivity_at_specificity: 1.0000 - val_specificity_at_sensitivity: 0.9958
# Epoch 12/50
# 105/105 [==============================] - 57s 541ms/step - loss: 0.0965 - accuracy: 0.9719 - precision: 0.4941 - recall: 0.9967 - sensitivity_at_specificity: 1.0000 - specificity_at_sensitivity: 0.9990 - val_loss: 0.7549 - val_accuracy: 0.8087 - val_precision: 0.5320 - val_recall: 0.9754 - val_sensitivity_at_specificity: 1.0000 - val_specificity_at_sensitivity: 0.9780
# Epoch 13/50
# 105/105 [==============================] - 58s 551ms/step - loss: 0.0972 - accuracy: 0.9733 - precision: 0.5119 - recall: 0.9962 - sensitivity_at_specificity: 1.0000 - specificity_at_sensitivity: 0.9992 - val_loss: 1.1084 - val_accuracy: 0.7197 - val_precision: 0.3498 - val_recall: 0.8845 - val_sensitivity_at_specificity: 1.0000 - val_specificity_at_sensitivity: 0.9890
# Epoch 14/50
# 105/105 [==============================] - 58s 550ms/step - loss: 0.1101 - accuracy: 0.9676 - precision: 0.4955 - recall: 0.9976 - sensitivity_at_specificity: 1.0000 - specificity_at_sensitivity: 0.9983 - val_loss: 0.2755 - val_accuracy: 0.9261 - val_precision: 0.4866 - val_recall: 0.9981 - val_sensitivity_at_specificity: 1.0000 - val_specificity_at_sensitivity: 0.9939
# Epoch 15/50
# 105/105 [==============================] - 57s 541ms/step - loss: 0.0815 - accuracy: 0.9776 - precision: 0.5087 - recall: 0.9971 - sensitivity_at_specificity: 1.0000 - specificity_at_sensitivity: 0.9991 - val_loss: 0.5485 - val_accuracy: 0.8542 - val_precision: 0.5105 - val_recall: 0.9205 - val_sensitivity_at_specificity: 1.0000 - val_specificity_at_sensitivity: 0.9958
# Epoch 16/50
# 105/105 [==============================] - 58s 552ms/step - loss: 0.0880 - accuracy: 0.9757 - precision: 0.5135 - recall: 0.9981 - sensitivity_at_specificity: 1.0000 - specificity_at_sensitivity: 0.9990 - val_loss: 4.0452 - val_accuracy: 0.5833 - val_precision: 0.3588 - val_recall: 0.8258 - val_sensitivity_at_specificity: 0.8352 - val_specificity_at_sensitivity: 0.9155
# Epoch 17/50
# 105/105 [==============================] - 58s 551ms/step - loss: 0.0822 - accuracy: 0.9752 - precision: 0.5101 - recall: 0.9990 - sensitivity_at_specificity: 1.0000 - specificity_at_sensitivity: 0.9992 - val_loss: 2.0080 - val_accuracy: 0.6345 - val_precision: 0.3728 - val_recall: 0.8239 - val_sensitivity_at_specificity: 1.0000 - val_specificity_at_sensitivity: 0.9417
# Epoch 18/50
# 105/105 [==============================] - 57s 544ms/step - loss: 0.1066 - accuracy: 0.9700 - precision: 0.5090 - recall: 0.9957 - sensitivity_at_specificity: 1.0000 - specificity_at_sensitivity: 0.9990 - val_loss: 0.4710 - val_accuracy: 0.8580 - val_precision: 0.4900 - val_recall: 0.9735 - val_sensitivity_at_specificity: 1.0000 - val_specificity_at_sensitivity: 0.9958
# Epoch 19/50
# 105/105 [==============================] - 58s 549ms/step - loss: 0.0525 - accuracy: 0.9857 - precision: 0.5165 - recall: 1.0000 - sensitivity_at_specificity: 1.0000 - specificity_at_sensitivity: 0.9990 - val_loss: 0.3786 - val_accuracy: 0.8996 - val_precision: 0.5418 - val_recall: 0.9564 - val_sensitivity_at_specificity: 1.0000 - val_specificity_at_sensitivity: 0.9989
# Epoch 20/50
# 105/105 [==============================] - 57s 542ms/step - loss: 0.0747 - accuracy: 0.9819 - precision: 0.4948 - recall: 0.9990 - sensitivity_at_specificity: 1.0000 - specificity_at_sensitivity: 0.9990 - val_loss: 0.9622 - val_accuracy: 0.8428 - val_precision: 0.3874 - val_recall: 0.8996 - val_sensitivity_at_specificity: 0.9943 - val_specificity_at_sensitivity: 0.9920
# Epoch 21/50
# 105/105 [==============================] - 59s 560ms/step - loss: 0.0317 - accuracy: 0.9924 - precision: 0.5345 - recall: 0.9990 - sensitivity_at_specificity: 1.0000 - specificity_at_sensitivity: 0.9998 - val_loss: 0.4932 - val_accuracy: 0.8485 - val_precision: 0.5195 - val_recall: 0.9830 - val_sensitivity_at_specificity: 1.0000 - val_specificity_at_sensitivity: 0.9973
# Epoch 22/50
# 105/105 [==============================] - 57s 540ms/step - loss: 0.0226 - accuracy: 0.9952 - precision: 0.5453 - recall: 0.9995 - sensitivity_at_specificity: 1.0000 - specificity_at_sensitivity: 0.9999 - val_loss: 0.1360 - val_accuracy: 0.9716 - val_precision: 0.5614 - val_recall: 0.9962 - val_sensitivity_at_specificity: 1.0000 - val_specificity_at_sensitivity: 0.9958
# Epoch 23/50
# 105/105 [==============================] - 57s 540ms/step - loss: 0.0344 - accuracy: 0.9910 - precision: 0.5332 - recall: 0.9990 - sensitivity_at_specificity: 1.0000 - specificity_at_sensitivity: 0.9992 - val_loss: 3.9717 - val_accuracy: 0.5436 - val_precision: 0.4357 - val_recall: 0.7955 - val_sensitivity_at_specificity: 1.0000 - val_specificity_at_sensitivity: 0.9133
# Epoch 24/50
# 105/105 [==============================] - 58s 549ms/step - loss: 0.0720 - accuracy: 0.9810 - precision: 0.5266 - recall: 0.9981 - sensitivity_at_specificity: 1.0000 - specificity_at_sensitivity: 0.9986 - val_loss: 0.2127 - val_accuracy: 0.9394 - val_precision: 0.5137 - val_recall: 0.9943 - val_sensitivity_at_specificity: 1.0000 - val_specificity_at_sensitivity: 0.9951
# Epoch 25/50
# 105/105 [==============================] - 57s 544ms/step - loss: 0.0834 - accuracy: 0.9781 - precision: 0.5189 - recall: 0.9976 - sensitivity_at_specificity: 1.0000 - specificity_at_sensitivity: 0.9979 - val_loss: 0.3100 - val_accuracy: 0.9356 - val_precision: 0.4636 - val_recall: 0.9886 - val_sensitivity_at_specificity: 1.0000 - val_specificity_at_sensitivity: 0.9947
# Epoch 26/50
# 105/105 [==============================] - 57s 539ms/step - loss: 0.0693 - accuracy: 0.9795 - precision: 0.5253 - recall: 0.9976 - sensitivity_at_specificity: 1.0000 - specificity_at_sensitivity: 0.9986 - val_loss: 0.3821 - val_accuracy: 0.9053 - val_precision: 0.4764 - val_recall: 0.9735 - val_sensitivity_at_specificity: 1.0000 - val_specificity_at_sensitivity: 0.9920
# Epoch 27/50
# 105/105 [==============================] - 57s 543ms/step - loss: 0.1178 - accuracy: 0.9652 - precision: 0.4957 - recall: 0.9967 - sensitivity_at_specificity: 1.0000 - specificity_at_sensitivity: 0.9986 - val_loss: 2.2510 - val_accuracy: 0.5928 - val_precision: 0.3581 - val_recall: 0.8220 - val_sensitivity_at_specificity: 0.9981 - val_specificity_at_sensitivity: 0.9307
# Epoch 28/50
# 105/105 [==============================] - 57s 539ms/step - loss: 0.0587 - accuracy: 0.9852 - precision: 0.5343 - recall: 0.9976 - sensitivity_at_specificity: 1.0000 - specificity_at_sensitivity: 0.9990 - val_loss: 0.4388 - val_accuracy: 0.9299 - val_precision: 0.4882 - val_recall: 0.9811 - val_sensitivity_at_specificity: 1.0000 - val_specificity_at_sensitivity: 0.9883
# Epoch 29/50
# 105/105 [==============================] - 57s 540ms/step - loss: 0.0558 - accuracy: 0.9829 - precision: 0.5151 - recall: 0.9995 - sensitivity_at_specificity: 1.0000 - specificity_at_sensitivity: 0.9993 - val_loss: 0.1217 - val_accuracy: 0.9659 - val_precision: 0.4664 - val_recall: 0.9981 - val_sensitivity_at_specificity: 1.0000 - val_specificity_at_sensitivity: 0.9977
# Epoch 30/50
# 105/105 [==============================] - 57s 540ms/step - loss: 0.0579 - accuracy: 0.9833 - precision: 0.4942 - recall: 0.9981 - sensitivity_at_specificity: 1.0000 - specificity_at_sensitivity: 0.9991 - val_loss: 0.1526 - val_accuracy: 0.9697 - val_precision: 0.4804 - val_recall: 0.9962 - val_sensitivity_at_specificity: 1.0000 - val_specificity_at_sensitivity: 0.9955
# Epoch 31/50
# 105/105 [==============================] - 57s 539ms/step - loss: 0.0589 - accuracy: 0.9857 - precision: 0.5094 - recall: 0.9962 - sensitivity_at_specificity: 1.0000 - specificity_at_sensitivity: 0.9991 - val_loss: 0.1478 - val_accuracy: 0.9659 - val_precision: 0.4360 - val_recall: 1.0000 - val_sensitivity_at_specificity: 1.0000 - val_specificity_at_sensitivity: 0.9962
# Epoch 32/50
# 105/105 [==============================] - 57s 538ms/step - loss: 0.0885 - accuracy: 0.9757 - precision: 0.5173 - recall: 0.9981 - sensitivity_at_specificity: 1.0000 - specificity_at_sensitivity: 0.9986 - val_loss: 0.1431 - val_accuracy: 0.9621 - val_precision: 0.5329 - val_recall: 0.9962 - val_sensitivity_at_specificity: 1.0000 - val_specificity_at_sensitivity: 0.9977
# Epoch 33/50
# 105/105 [==============================] - 57s 540ms/step - loss: 0.0344 - accuracy: 0.9895 - precision: 0.5436 - recall: 0.9981 - sensitivity_at_specificity: 1.0000 - specificity_at_sensitivity: 0.9994 - val_loss: 0.2037 - val_accuracy: 0.9451 - val_precision: 0.6146 - val_recall: 0.9905 - val_sensitivity_at_specificity: 1.0000 - val_specificity_at_sensitivity: 0.9973
# Epoch 34/50
# 105/105 [==============================] - 56s 537ms/step - loss: 0.0518 - accuracy: 0.9881 - precision: 0.5609 - recall: 0.9976 - sensitivity_at_specificity: 1.0000 - specificity_at_sensitivity: 0.9994 - val_loss: 0.3532 - val_accuracy: 0.8636 - val_precision: 0.4874 - val_recall: 0.9905 - val_sensitivity_at_specificity: 1.0000 - val_specificity_at_sensitivity: 0.9958
# Epoch 35/50
# 105/105 [==============================] - 56s 535ms/step - loss: 0.0463 - accuracy: 0.9890 - precision: 0.5346 - recall: 0.9981 - sensitivity_at_specificity: 1.0000 - specificity_at_sensitivity: 0.9994 - val_loss: 0.9223 - val_accuracy: 0.7633 - val_precision: 0.5278 - val_recall: 0.9356 - val_sensitivity_at_specificity: 0.9981 - val_specificity_at_sensitivity: 0.9875
# Epoch 36/50
# 105/105 [==============================] - 57s 538ms/step - loss: 0.0330 - accuracy: 0.9919 - precision: 0.5245 - recall: 0.9990 - sensitivity_at_specificity: 1.0000 - specificity_at_sensitivity: 0.9996 - val_loss: 0.2897 - val_accuracy: 0.9451 - val_precision: 0.5398 - val_recall: 0.9886 - val_sensitivity_at_specificity: 1.0000 - val_specificity_at_sensitivity: 0.9943
# Epoch 37/50
# 105/105 [==============================] - 57s 543ms/step - loss: 0.1056 - accuracy: 0.9738 - precision: 0.4935 - recall: 0.9986 - sensitivity_at_specificity: 1.0000 - specificity_at_sensitivity: 0.9970 - val_loss: 0.5132 - val_accuracy: 0.8769 - val_precision: 0.4319 - val_recall: 0.9489 - val_sensitivity_at_specificity: 0.9924 - val_specificity_at_sensitivity: 0.9958
# Epoch 38/50
# 105/105 [==============================] - 57s 541ms/step - loss: 0.0958 - accuracy: 0.9748 - precision: 0.4869 - recall: 0.9971 - sensitivity_at_specificity: 1.0000 - specificity_at_sensitivity: 0.9982 - val_loss: 0.1606 - val_accuracy: 0.9508 - val_precision: 0.4273 - val_recall: 0.9962 - val_sensitivity_at_specificity: 1.0000 - val_specificity_at_sensitivity: 0.9981
# Epoch 39/50
# 105/105 [==============================] - 57s 539ms/step - loss: 0.0688 - accuracy: 0.9843 - precision: 0.5068 - recall: 0.9990 - sensitivity_at_specificity: 1.0000 - specificity_at_sensitivity: 0.9987 - val_loss: 0.8947 - val_accuracy: 0.7936 - val_precision: 0.4190 - val_recall: 0.9602 - val_sensitivity_at_specificity: 1.0000 - val_specificity_at_sensitivity: 0.9777
# Epoch 40/50
# 105/105 [==============================] - 57s 546ms/step - loss: 0.1077 - accuracy: 0.9724 - precision: 0.4722 - recall: 0.9957 - sensitivity_at_specificity: 1.0000 - specificity_at_sensitivity: 0.9975 - val_loss: 6.1946 - val_accuracy: 0.4527 - val_precision: 0.3323 - val_recall: 0.6269 - val_sensitivity_at_specificity: 0.8864 - val_specificity_at_sensitivity: 0.8985
# Epoch 41/50
# 105/105 [==============================] - 57s 543ms/step - loss: 0.0635 - accuracy: 0.9857 - precision: 0.5045 - recall: 0.9962 - sensitivity_at_specificity: 0.9995 - specificity_at_sensitivity: 0.9992 - val_loss: 0.5660 - val_accuracy: 0.8636 - val_precision: 0.6040 - val_recall: 0.9678 - val_sensitivity_at_specificity: 1.0000 - val_specificity_at_sensitivity: 0.9894
# Epoch 42/50
# 105/105 [==============================] - 57s 548ms/step - loss: 0.0596 - accuracy: 0.9819 - precision: 0.5228 - recall: 0.9981 - sensitivity_at_specificity: 1.0000 - specificity_at_sensitivity: 0.9989 - val_loss: 0.2827 - val_accuracy: 0.9375 - val_precision: 0.5299 - val_recall: 0.9905 - val_sensitivity_at_specificity: 1.0000 - val_specificity_at_sensitivity: 0.9951
# Epoch 43/50
# 105/105 [==============================] - 57s 543ms/step - loss: 0.0448 - accuracy: 0.9881 - precision: 0.5185 - recall: 0.9995 - sensitivity_at_specificity: 1.0000 - specificity_at_sensitivity: 0.9989 - val_loss: 0.6573 - val_accuracy: 0.8788 - val_precision: 0.5052 - val_recall: 0.9242 - val_sensitivity_at_specificity: 0.9981 - val_specificity_at_sensitivity: 0.9932
# Epoch 44/50
# 105/105 [==============================] - 58s 551ms/step - loss: 0.0456 - accuracy: 0.9905 - precision: 0.5332 - recall: 0.9976 - sensitivity_at_specificity: 1.0000 - specificity_at_sensitivity: 0.9994 - val_loss: 0.7712 - val_accuracy: 0.8371 - val_precision: 0.5126 - val_recall: 0.9280 - val_sensitivity_at_specificity: 1.0000 - val_specificity_at_sensitivity: 0.9864
# Epoch 45/50
# 105/105 [==============================] - 57s 546ms/step - loss: 0.0622 - accuracy: 0.9829 - precision: 0.5316 - recall: 0.9986 - sensitivity_at_specificity: 1.0000 - specificity_at_sensitivity: 0.9990 - val_loss: 0.1584 - val_accuracy: 0.9583 - val_precision: 0.5279 - val_recall: 0.9848 - val_sensitivity_at_specificity: 1.0000 - val_specificity_at_sensitivity: 0.9985
# Epoch 46/50
# 105/105 [==============================] - 57s 542ms/step - loss: 0.0432 - accuracy: 0.9890 - precision: 0.5341 - recall: 0.9986 - sensitivity_at_specificity: 1.0000 - specificity_at_sensitivity: 0.9991 - val_loss: 0.1249 - val_accuracy: 0.9545 - val_precision: 0.5249 - val_recall: 1.0000 - val_sensitivity_at_specificity: 1.0000 - val_specificity_at_sensitivity: 0.9989
# Epoch 47/50
# 105/105 [==============================] - 58s 550ms/step - loss: 0.0129 - accuracy: 0.9971 - precision: 0.5554 - recall: 0.9995 - sensitivity_at_specificity: 1.0000 - specificity_at_sensitivity: 1.0000 - val_loss: 0.2252 - val_accuracy: 0.9451 - val_precision: 0.5896 - val_recall: 0.9905 - val_sensitivity_at_specificity: 1.0000 - val_specificity_at_sensitivity: 0.9970
# Epoch 48/50
# 105/105 [==============================] - 58s 549ms/step - loss: 0.0072 - accuracy: 0.9986 - precision: 0.5666 - recall: 1.0000 - sensitivity_at_specificity: 1.0000 - specificity_at_sensitivity: 0.9999 - val_loss: 1.1027 - val_accuracy: 0.9072 - val_precision: 0.5692 - val_recall: 0.9811 - val_sensitivity_at_specificity: 0.9962 - val_specificity_at_sensitivity: 0.9939
# Epoch 49/50
# 105/105 [==============================] - 58s 546ms/step - loss: 0.0169 - accuracy: 0.9943 - precision: 0.5495 - recall: 1.0000 - sensitivity_at_specificity: 1.0000 - specificity_at_sensitivity: 0.9996 - val_loss: 0.1922 - val_accuracy: 0.9697 - val_precision: 0.5939 - val_recall: 0.9943 - val_sensitivity_at_specificity: 1.0000 - val_specificity_at_sensitivity: 0.9947
# Epoch 50/50
# 105/105 [==============================] - 58s 549ms/step - loss: 0.0621 - accuracy: 0.9852 - precision: 0.5256 - recall: 0.9976 - sensitivity_at_specificity: 1.0000 - specificity_at_sensitivity: 0.9986 - val_loss: 0.2107 - val_accuracy: 0.9432 - val_precision: 0.4811 - val_recall: 0.9867 - val_sensitivity_at_specificity: 1.0000 - val_specificity_at_sensitivity: 0.9985

# %%
fig, ax = plt.subplots(2,1)
ax[0].plot(hist8.history['accuracy'], color='b', label="Training accuracy")
ax[0].plot(hist8.history['val_accuracy'], color='r',label="Validation accuracy")
legend = ax[0].legend(loc='best', shadow=True)

ax[1].plot(hist8.history['loss'], color='b', label="Training loss")
ax[1].plot(hist8.history['val_loss'], color='r', label="validation loss",axes =ax[1])
legend = ax[1].legend(loc='best', shadow=True)

# %%
fig, ax = plt.subplots(2,1)
ax[0].plot(hist8.history['precision'], color='b', label="Training precision")
ax[0].plot(hist8.history['val_precision'], color='r',label="Validation precision")
legend = ax[0].legend(loc='best', shadow=True)

ax[1].plot(hist8.history['loss'], color='b', label="Training loss")
ax[1].plot(hist8.history['val_loss'], color='r', label="validation loss",axes =ax[1])
legend = ax[1].legend(loc='best', shadow=True)

# %%
fig, ax = plt.subplots(2,1)
ax[0].plot(hist8.history['recall'], color='b', label="Training recall")
ax[0].plot(hist8.history['val_recall'], color='r',label="Validation recall")
legend = ax[0].legend(loc='best', shadow=True)

ax[1].plot(hist8.history['loss'], color='b', label="Training loss")
ax[1].plot(hist8.history['val_loss'], color='r', label="validation loss",axes =ax[1])
legend = ax[1].legend(loc='best', shadow=True)

# %%
fig, ax = plt.subplots(2,1)
ax[0].plot(hist8.history['sensitivity_at_specificity'], color='b', label="Training sensitivity")
ax[0].plot(hist8.history['val_sensitivity_at_specificity'], color='r',label="Validation sensitivity")
legend = ax[0].legend(loc='best', shadow=True)

ax[1].plot(hist8.history['loss'], color='b', label="Training loss")
ax[1].plot(hist8.history['val_loss'], color='r', label="validation loss",axes =ax[1])
legend = ax[1].legend(loc='best', shadow=True)

# %%
fig, ax = plt.subplots(2,1)
ax[0].plot(hist8.history['specificity_at_sensitivity'], color='b', label="Training specificity")
ax[0].plot(hist8.history['val_specificity_at_sensitivity'], color='r',label="Validation specificity")
legend = ax[0].legend(loc='best', shadow=True)

ax[1].plot(hist8.history['loss'], color='b', label="Training loss")
ax[1].plot(hist8.history['val_loss'], color='r', label="validation loss",axes =ax[1])
legend = ax[1].legend(loc='best', shadow=True)

# %%
filenames = test_generator.filenames
nb_samples = len(filenames)
model1_predict = model1.predict_generator(test_generator,steps = nb_samples, verbose=2)
# Out:
# c:\Users\0258\.conda\envs\deepfake\lib\site-packages\keras\engine\training.py:2035: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   warnings.warn('`Model.predict_generator` is deprecated and '
# WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 528 batches). You may need to use the repeat() function when building your dataset.
# 528/528 - 12s

# %%
y_true = test_generator.classes
y_pred = model_predict.argmax(axis=1)
plot_confusion_matrix(y_true, y_pred, classes=['Bacterial_leaf_blight', 'Brown_spot','Healthy','Leaf_blast','Leaf_scald','Narrow_brown_spot'],
                      title='Confusion matrix')
# Out:
# Confusion matrix, without normalization
# [[14 21 14 12 14 13]
#  [14 14 11 13 18 18]
#  [14  9 21 17 10 17]
#  [19  8 11 14 18 18]
#  [13 10 14 14 20 17]
#  [17 19 16 10 14 12]]
# <AxesSubplot:title={'center':'Confusion matrix'}, xlabel='Predicted label', ylabel='True label'>
